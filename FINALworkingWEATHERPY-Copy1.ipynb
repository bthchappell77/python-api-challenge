# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
api_key
# Out:
# '6a4a37dbaae24ce1eef54ad57e7c2e24'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 649

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set up lists to hold response info
lat = []
temp_max = []
hum = []
cloud = []
wind = []
long = []
city_api = []
country = []
datetime_api = []
id_counter = []

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="


    # Loop through the list of cities and perform a request for data on each
for i, city in enumerate(cities):
        weather_response = requests.get(query_url + city)
        weather_json = weather_response.json()
        #Error handling
        try:
            
            city_id = weather_json["id"]
            city_name = weather_json["name"]
        
        # Add a one second interval between queries to stay within API query limits
            time.sleep(1)
    
            response = requests.get(query_url + city).json()
            lat.append(response['coord']['lat'])
            long.append(response['coord']['lon'])
            temp_max.append(response['main']['temp_max'])
            hum.append(response['main']['humidity'])
            cloud.append(response['clouds']['all'])
            wind.append(response['wind']['speed'])
            country.append(response['sys']['country'])
            city_api.append(response["name"])
            datetime_api.append(response["dt"])
            
            #print(f"Retrieving information for City: {city_name} and City ID is: {city_id} ")
            print("Retrieving information for City #%d, City Name: %s" % 
             (i, city))
        except (KeyError, IndexError):
            print(f"Missing information for City: {city_name}. Skipping city.")
# Out:
# Retrieving information for City #0, City Name: albany
# Missing information for City: Albany. Skipping city.
# Retrieving information for City #2, City Name: upernavik
# Retrieving information for City #3, City Name: faanui
# Retrieving information for City #4, City Name: yumen
# Retrieving information for City #5, City Name: kodiak
# Retrieving information for City #6, City Name: phuket
# Retrieving information for City #7, City Name: grocka
# Retrieving information for City #8, City Name: kapaa
# Retrieving information for City #9, City Name: kasama
# Retrieving information for City #10, City Name: port hardy
# Retrieving information for City #11, City Name: hofn
# Retrieving information for City #12, City Name: fort nelson
# Retrieving information for City #13, City Name: barrow
# Retrieving information for City #14, City Name: punta arenas
# Retrieving information for City #15, City Name: pamekasan
# Retrieving information for City #16, City Name: puerto escondido
# Retrieving information for City #17, City Name: rocha
# Retrieving information for City #18, City Name: contai
# Retrieving information for City #19, City Name: castro
# Retrieving information for City #20, City Name: cartagena del chaira
# Retrieving information for City #21, City Name: qaanaaq
# Retrieving information for City #22, City Name: haines junction
# Retrieving information for City #23, City Name: vilhena
# Retrieving information for City #24, City Name: bredasdorp
# Retrieving information for City #25, City Name: hithadhoo
# Retrieving information for City #26, City Name: saskylakh
# Retrieving information for City #27, City Name: rikitea
# Retrieving information for City #28, City Name: ouadda
# Retrieving information for City #29, City Name: jamestown
# Retrieving information for City #30, City Name: hoopstad
# Retrieving information for City #31, City Name: mataura
# Retrieving information for City #32, City Name: marquette
# Retrieving information for City #33, City Name: khatanga
# Retrieving information for City #34, City Name: yar-sale
# Retrieving information for City #35, City Name: kalmunai
# Retrieving information for City #36, City Name: cravo norte
# Retrieving information for City #37, City Name: daru
# Retrieving information for City #38, City Name: vytegra
# Retrieving information for City #39, City Name: broome
# Retrieving information for City #40, City Name: chuy
# Retrieving information for City #41, City Name: ushuaia
# Missing information for City: Ushuaia. Skipping city.
# Retrieving information for City #43, City Name: bilma
# Retrieving information for City #44, City Name: yellowknife
# Retrieving information for City #45, City Name: atuona
# Retrieving information for City #46, City Name: tasiilaq
# Retrieving information for City #47, City Name: araouane
# Retrieving information for City #48, City Name: nome
# Retrieving information for City #49, City Name: ixtapa
# Retrieving information for City #50, City Name: lasa
# Retrieving information for City #51, City Name: cape town
# Retrieving information for City #52, City Name: praia
# Retrieving information for City #53, City Name: souillac
# Missing information for City: Souillac. Skipping city.
# Retrieving information for City #55, City Name: rio gallegos
# Retrieving information for City #56, City Name: port alfred
# Retrieving information for City #57, City Name: mucurici
# Retrieving information for City #58, City Name: hamilton
# Retrieving information for City #59, City Name: buka
# Retrieving information for City #60, City Name: ribeira grande
# Retrieving information for City #61, City Name: naze
# Retrieving information for City #62, City Name: nishihara
# Retrieving information for City #63, City Name: puerto ayora
# Retrieving information for City #64, City Name: katsuura
# Retrieving information for City #65, City Name: butaritari
# Retrieving information for City #66, City Name: mocuba
# Missing information for City: Mocuba. Skipping city.
# Retrieving information for City #68, City Name: new norfolk
# Retrieving information for City #69, City Name: dikson
# Retrieving information for City #70, City Name: lagoa
# Retrieving information for City #71, City Name: manokwari
# Retrieving information for City #72, City Name: jasper
# Retrieving information for City #73, City Name: port macquarie
# Retrieving information for City #74, City Name: pevek
# Retrieving information for City #75, City Name: arraial do cabo
# Retrieving information for City #76, City Name: guerrero negro
# Retrieving information for City #77, City Name: majdanpek
# Retrieving information for City #78, City Name: bluff
# Retrieving information for City #79, City Name: pisco
# Retrieving information for City #80, City Name: sao filipe
# Retrieving information for City #81, City Name: acapulco
# Retrieving information for City #82, City Name: sugod
# Retrieving information for City #83, City Name: vaini
# Retrieving information for City #84, City Name: thompson
# Retrieving information for City #85, City Name: nieuw amsterdam
# Retrieving information for City #86, City Name: charters towers
# Retrieving information for City #87, City Name: airai
# Retrieving information for City #88, City Name: busselton
# Retrieving information for City #89, City Name: camalu
# Retrieving information for City #90, City Name: pangani
# Missing information for City: Pangani. Skipping city.
# Retrieving information for City #92, City Name: baiyin
# Retrieving information for City #93, City Name: port elizabeth
# Missing information for City: Port Elizabeth. Skipping city.
# Retrieving information for City #95, City Name: zhigansk
# Retrieving information for City #96, City Name: jaguey grande
# Retrieving information for City #97, City Name: igarka
# Retrieving information for City #98, City Name: karratha
# Retrieving information for City #99, City Name: atambua
# Retrieving information for City #100, City Name: sur
# Retrieving information for City #101, City Name: manicore
# Retrieving information for City #102, City Name: aniva
# Retrieving information for City #103, City Name: iqaluit
# Retrieving information for City #104, City Name: vardo
# Retrieving information for City #105, City Name: ancud
# Retrieving information for City #106, City Name: carnarvon
# Missing information for City: Carnarvon. Skipping city.
# Retrieving information for City #108, City Name: starosubkhangulovo
# Retrieving information for City #109, City Name: bambous virieux
# Retrieving information for City #110, City Name: salalah
# Retrieving information for City #111, City Name: burgeo
# Missing information for City: Burgeo. Skipping city.
# Retrieving information for City #113, City Name: aksarka
# Retrieving information for City #114, City Name: dawlatabad
# Retrieving information for City #115, City Name: omagh
# Retrieving information for City #116, City Name: saint-philippe
# Retrieving information for City #117, City Name: tuy hoa
# Retrieving information for City #118, City Name: avarua
# Retrieving information for City #119, City Name: sao joao da barra
# Retrieving information for City #120, City Name: bhawanipatna
# Retrieving information for City #121, City Name: ketchikan
# Retrieving information for City #122, City Name: mar del plata
# Retrieving information for City #123, City Name: shenjiamen
# Retrieving information for City #124, City Name: hilo
# Retrieving information for City #125, City Name: port lincoln
# Retrieving information for City #126, City Name: oranjemund
# Retrieving information for City #127, City Name: hermanus
# Retrieving information for City #128, City Name: mayo
# Retrieving information for City #129, City Name: kaduy
# Retrieving information for City #130, City Name: isangel
# Retrieving information for City #131, City Name: sanandaj
# Retrieving information for City #132, City Name: severo-kurilsk
# Retrieving information for City #133, City Name: leca da palmeira
# Retrieving information for City #134, City Name: ewa beach
# Retrieving information for City #135, City Name: chongwe
# Retrieving information for City #136, City Name: norman wells
# Retrieving information for City #137, City Name: susanville
# Retrieving information for City #138, City Name: shelabolikha
# Retrieving information for City #139, City Name: poum
# Retrieving information for City #140, City Name: gornopravdinsk
# Retrieving information for City #141, City Name: chalette-sur-loing
# Retrieving information for City #142, City Name: hudson bay
# Missing information for City: Hudson Bay. Skipping city.
# Retrieving information for City #144, City Name: batemans bay
# Retrieving information for City #145, City Name: flin flon
# Retrieving information for City #146, City Name: tonala
# Retrieving information for City #147, City Name: klaksvik
# Retrieving information for City #148, City Name: ulaanbaatar
# Retrieving information for City #149, City Name: provideniya
# Retrieving information for City #150, City Name: kalikino
# Retrieving information for City #151, City Name: ponta do sol
# Missing information for City: Ponta do Sol. Skipping city.
# Retrieving information for City #153, City Name: plettenberg bay
# Retrieving information for City #154, City Name: san juan
# Missing information for City: San Juan. Skipping city.
# Missing information for City: San Juan. Skipping city.
# Retrieving information for City #157, City Name: kaitangata
# Retrieving information for City #158, City Name: esperance
# Retrieving information for City #159, City Name: yulara
# Retrieving information for City #160, City Name: mahebourg
# Retrieving information for City #161, City Name: kiruna
# Retrieving information for City #162, City Name: east london
# Retrieving information for City #163, City Name: port blair
# Retrieving information for City #164, City Name: waitati
# Retrieving information for City #165, City Name: gubkinskiy
# Retrieving information for City #166, City Name: talcahuano
# Missing information for City: Talcahuano. Skipping city.
# Retrieving information for City #168, City Name: port-gentil
# Retrieving information for City #169, City Name: tuatapere
# Retrieving information for City #170, City Name: vagur
# Retrieving information for City #171, City Name: flinders
# Retrieving information for City #172, City Name: kurlovo
# Retrieving information for City #173, City Name: talnakh
# Retrieving information for City #174, City Name: raudeberg
# Retrieving information for City #175, City Name: chulym
# Retrieving information for City #176, City Name: cabedelo
# Retrieving information for City #177, City Name: beringovskiy
# Retrieving information for City #178, City Name: lethem
# Retrieving information for City #179, City Name: pacific grove
# Retrieving information for City #180, City Name: hasaki
# Retrieving information for City #181, City Name: tyulgan
# Retrieving information for City #182, City Name: dunedin
# Retrieving information for City #183, City Name: chakulia
# Missing information for City: Chakulia. Skipping city.
# Retrieving information for City #185, City Name: husavik
# Retrieving information for City #186, City Name: belaya gora
# Retrieving information for City #187, City Name: gebre guracha
# Retrieving information for City #188, City Name: college
# Retrieving information for City #189, City Name: plastun
# Retrieving information for City #190, City Name: hobart
# Retrieving information for City #191, City Name: chermoz
# Retrieving information for City #192, City Name: portobelo
# Retrieving information for City #193, City Name: phillipsburg
# Retrieving information for City #194, City Name: constitucion
# Retrieving information for City #195, City Name: moron
# Retrieving information for City #196, City Name: faya
# Retrieving information for City #197, City Name: namatanai
# Retrieving information for City #198, City Name: krasnogorsk
# Retrieving information for City #199, City Name: tsabong
# Retrieving information for City #200, City Name: ishigaki
# Retrieving information for City #201, City Name: lagunas
# Missing information for City: Lagunas. Skipping city.
# Retrieving information for City #203, City Name: omsukchan
# Retrieving information for City #204, City Name: cam ranh
# Retrieving information for City #205, City Name: clyde river
# Retrieving information for City #206, City Name: ballina
# Retrieving information for City #207, City Name: kant
# Retrieving information for City #208, City Name: santa fe
# Retrieving information for City #209, City Name: tabasalu
# Retrieving information for City #210, City Name: boa vista
# Retrieving information for City #211, City Name: fukue
# Retrieving information for City #212, City Name: vila
# Retrieving information for City #213, City Name: zinder
# Retrieving information for City #214, City Name: chichimila
# Missing information for City: Chichimila. Skipping city.
# Retrieving information for City #216, City Name: homer
# Retrieving information for City #217, City Name: san policarpo
# Missing information for City: San Policarpo. Skipping city.
# Retrieving information for City #219, City Name: bethel
# Retrieving information for City #220, City Name: port hedland
# Retrieving information for City #221, City Name: hattiesburg
# Missing information for City: Hattiesburg. Skipping city.
# Retrieving information for City #223, City Name: georgetown
# Retrieving information for City #224, City Name: bosaso
# Retrieving information for City #225, City Name: knysna
# Retrieving information for City #226, City Name: tigre
# Retrieving information for City #227, City Name: lima
# Retrieving information for City #228, City Name: nikolskoye
# Retrieving information for City #229, City Name: fairhaven
# Retrieving information for City #230, City Name: praia da vitoria
# Retrieving information for City #231, City Name: mitsamiouli
# Retrieving information for City #232, City Name: labuhan
# Retrieving information for City #233, City Name: wanning
# Retrieving information for City #234, City Name: sioux lookout
# Retrieving information for City #235, City Name: meulaboh
# Retrieving information for City #236, City Name: geraldton
# Retrieving information for City #237, City Name: cidreira
# Retrieving information for City #238, City Name: vila franca do campo
# Retrieving information for City #239, City Name: svetlogorsk
# Retrieving information for City #240, City Name: gazojak
# Retrieving information for City #241, City Name: darhan
# Retrieving information for City #242, City Name: oksfjord
# Retrieving information for City #243, City Name: union
# Retrieving information for City #244, City Name: ginir
# Retrieving information for City #245, City Name: beloha
# Retrieving information for City #246, City Name: komsomolskiy
# Retrieving information for City #247, City Name: san luis de gaceno
# Retrieving information for City #248, City Name: saint george
# Retrieving information for City #249, City Name: dicabisagan
# Retrieving information for City #250, City Name: pangnirtung
# Retrieving information for City #251, City Name: maniitsoq
# Retrieving information for City #252, City Name: shelburne
# Retrieving information for City #253, City Name: axim
# Missing information for City: Axim. Skipping city.
# Retrieving information for City #255, City Name: sovetskiy
# Retrieving information for City #256, City Name: luderitz
# Retrieving information for City #257, City Name: alta gracia
# Retrieving information for City #258, City Name: staroaleyskoye
# Retrieving information for City #259, City Name: hualmay
# Retrieving information for City #260, City Name: barmer
# Missing information for City: Barmer. Skipping city.
# Retrieving information for City #262, City Name: san jose
# Retrieving information for City #263, City Name: saldanha
# Retrieving information for City #264, City Name: santo amaro da imperatriz
# Retrieving information for City #265, City Name: la palma
# Retrieving information for City #266, City Name: harper
# Retrieving information for City #267, City Name: novoagansk
# Retrieving information for City #268, City Name: severobaykalsk
# Retrieving information for City #269, City Name: cap malheureux
# Retrieving information for City #270, City Name: leningradskiy
# Retrieving information for City #271, City Name: byron bay
# Retrieving information for City #272, City Name: shaunavon
# Retrieving information for City #273, City Name: sao francisco
# Retrieving information for City #274, City Name: fortuna
# Retrieving information for City #275, City Name: erenhot
# Retrieving information for City #276, City Name: nemuro
# Retrieving information for City #277, City Name: hobyo
# Retrieving information for City #278, City Name: cayenne
# Retrieving information for City #279, City Name: chenzhou
# Retrieving information for City #280, City Name: sechenovo
# Missing information for City: Sechenovo. Skipping city.
# Retrieving information for City #282, City Name: leopold
# Retrieving information for City #283, City Name: codrington
# Retrieving information for City #284, City Name: bondoukou
# Retrieving information for City #285, City Name: la ronge
# Missing information for City: La Ronge. Skipping city.
# Retrieving information for City #287, City Name: monrovia
# Retrieving information for City #288, City Name: guarapari
# Retrieving information for City #289, City Name: inhambane
# Missing information for City: Inhambane. Skipping city.
# Retrieving information for City #291, City Name: tilichiki
# Missing information for City: Tilichiki. Skipping city.
# Retrieving information for City #293, City Name: samarai
# Retrieving information for City #294, City Name: tabas
# Retrieving information for City #295, City Name: sierpc
# Missing information for City: Sierpc. Skipping city.
# Retrieving information for City #297, City Name: tiksi
# Retrieving information for City #298, City Name: hami
# Retrieving information for City #299, City Name: hanna
# Retrieving information for City #300, City Name: chokurdakh
# Retrieving information for City #301, City Name: duluth
# Retrieving information for City #302, City Name: berdigestyakh
# Retrieving information for City #303, City Name: gornyy
# Retrieving information for City #304, City Name: lavrentiya
# Retrieving information for City #305, City Name: northallerton
# Retrieving information for City #306, City Name: zharkent
# Retrieving information for City #307, City Name: ugoofaaru
# Retrieving information for City #308, City Name: santa cruz
# Retrieving information for City #309, City Name: canutama
# Retrieving information for City #310, City Name: pundaguitan
# Retrieving information for City #311, City Name: ilulissat
# Retrieving information for City #312, City Name: oyotun
# Retrieving information for City #313, City Name: cruz alta
# Retrieving information for City #314, City Name: altamira
# Retrieving information for City #315, City Name: yuzhno-kurilsk
# Missing information for City: Yuzhno-Kurilsk. Skipping city.
# Retrieving information for City #317, City Name: cartagena
# Retrieving information for City #318, City Name: longyearbyen
# Retrieving information for City #319, City Name: pindiga
# Retrieving information for City #320, City Name: walvis bay
# Retrieving information for City #321, City Name: viedma
# Retrieving information for City #322, City Name: padang
# Retrieving information for City #323, City Name: ulladulla
# Retrieving information for City #324, City Name: elesbao veloso
# Retrieving information for City #325, City Name: buraydah
# Retrieving information for City #326, City Name: coari
# Retrieving information for City #327, City Name: palm coast
# Retrieving information for City #328, City Name: hachinohe
# Retrieving information for City #329, City Name: manzil salim
# Retrieving information for City #330, City Name: ihosy
# Retrieving information for City #331, City Name: dawei
# Retrieving information for City #332, City Name: hervey bay
# Retrieving information for City #333, City Name: dwarka
# Retrieving information for City #334, City Name: burnie
# Retrieving information for City #335, City Name: tuktoyaktuk
# Retrieving information for City #336, City Name: mao
# Missing information for City: Mao. Skipping city.
# Retrieving information for City #338, City Name: alice springs
# Retrieving information for City #339, City Name: tamandare
# Retrieving information for City #340, City Name: paamiut
# Retrieving information for City #341, City Name: benghazi
# Retrieving information for City #342, City Name: zuwarah
# Retrieving information for City #343, City Name: cabo san lucas
# Retrieving information for City #344, City Name: muros
# Retrieving information for City #345, City Name: buin
# Retrieving information for City #346, City Name: aklavik
# Retrieving information for City #347, City Name: lovozero
# Retrieving information for City #348, City Name: nouadhibou
# Retrieving information for City #349, City Name: villarrica
# Retrieving information for City #350, City Name: lata
# Retrieving information for City #351, City Name: chapais
# Retrieving information for City #352, City Name: narsaq
# Retrieving information for City #353, City Name: te anau
# Retrieving information for City #354, City Name: benjamin aceval
# Retrieving information for City #355, City Name: khonsa
# Retrieving information for City #356, City Name: sovetskaya gavan
# Missing information for City: Sovetskaya Gavan. Skipping city.
# Missing information for City: Sovetskaya Gavan. Skipping city.
# Retrieving information for City #359, City Name: surt
# Retrieving information for City #360, City Name: huntington
# Missing information for City: Huntington. Skipping city.
# Retrieving information for City #362, City Name: diego de almagro
# Retrieving information for City #363, City Name: longyan
# Retrieving information for City #364, City Name: franca
# Retrieving information for City #365, City Name: osypenko
# Retrieving information for City #366, City Name: nizhniy ingash
# Retrieving information for City #367, City Name: bartica
# Missing information for City: Bartica. Skipping city.
# Missing information for City: Bartica. Skipping city.
# Retrieving information for City #370, City Name: tipitapa
# Retrieving information for City #371, City Name: marsa matruh
# Retrieving information for City #372, City Name: grand-santi
# Retrieving information for City #373, City Name: amapa
# Retrieving information for City #374, City Name: cordoba
# Retrieving information for City #375, City Name: kitob
# Retrieving information for City #376, City Name: hede
# Retrieving information for City #377, City Name: ouagadougou
# Retrieving information for City #378, City Name: orleans
# Retrieving information for City #379, City Name: guaruja
# Retrieving information for City #380, City Name: kenai
# Retrieving information for City #381, City Name: chistogorskiy
# Retrieving information for City #382, City Name: touros
# Retrieving information for City #383, City Name: kushiro
# Retrieving information for City #384, City Name: bilibino
# Missing information for City: Bilibino. Skipping city.
# Retrieving information for City #386, City Name: antsohihy
# Retrieving information for City #387, City Name: skjervoy
# Retrieving information for City #388, City Name: teluknaga
# Retrieving information for City #389, City Name: jacareacanga
# Retrieving information for City #390, City Name: bom jesus
# Retrieving information for City #391, City Name: copala
# Retrieving information for City #392, City Name: mehamn
# Retrieving information for City #393, City Name: mbandaka
# Retrieving information for City #394, City Name: gamba
# Retrieving information for City #395, City Name: mitu
# Missing information for City: Mitu. Skipping city.
# Missing information for City: Mitu. Skipping city.
# Retrieving information for City #398, City Name: coffs harbour
# Retrieving information for City #399, City Name: noumea
# Retrieving information for City #400, City Name: abu dhabi
# Retrieving information for City #401, City Name: mount gambier
# Retrieving information for City #402, City Name: torbay
# Retrieving information for City #403, City Name: pokhara
# Retrieving information for City #404, City Name: biankouma
# Retrieving information for City #405, City Name: srednekolymsk
# Retrieving information for City #406, City Name: goderich
# Retrieving information for City #407, City Name: port keats
# Retrieving information for City #408, City Name: camargo
# Retrieving information for City #409, City Name: auki
# Retrieving information for City #410, City Name: isla mujeres
# Missing information for City: Isla Mujeres. Skipping city.
# Missing information for City: Isla Mujeres. Skipping city.
# Retrieving information for City #413, City Name: statesboro
# Retrieving information for City #414, City Name: humaita
# Retrieving information for City #415, City Name: kuandian
# Retrieving information for City #416, City Name: kavieng
# Missing information for City: Kavieng. Skipping city.
# Retrieving information for City #418, City Name: laguna
# Retrieving information for City #419, City Name: kahului
# Retrieving information for City #420, City Name: ouallam
# Retrieving information for City #421, City Name: sorland
# Retrieving information for City #422, City Name: mandapam
# Retrieving information for City #423, City Name: kavaratti
# Retrieving information for City #424, City Name: maragogi
# Retrieving information for City #425, City Name: mezen
# Retrieving information for City #426, City Name: bella vista
# Retrieving information for City #427, City Name: maumere
# Missing information for City: Maumere. Skipping city.
# Retrieving information for City #429, City Name: kumo
# Missing information for City: Kumo. Skipping city.
# Retrieving information for City #431, City Name: nichinan
# Retrieving information for City #432, City Name: okato
# Retrieving information for City #433, City Name: ajdabiya
# Retrieving information for City #434, City Name: dingle
# Retrieving information for City #435, City Name: mayen
# Retrieving information for City #436, City Name: samfya
# Retrieving information for City #437, City Name: pointe-noire
# Retrieving information for City #438, City Name: kasongo-lunda
# Retrieving information for City #439, City Name: sovetskaya
# Retrieving information for City #440, City Name: waipawa
# Retrieving information for City #441, City Name: lensk
# Retrieving information for City #442, City Name: asosa
# Retrieving information for City #443, City Name: oneonta
# Retrieving information for City #444, City Name: sal rei
# Retrieving information for City #445, City Name: abalak
# Retrieving information for City #446, City Name: vestmannaeyjar
# Missing information for City: Vestmannaeyjar. Skipping city.
# Retrieving information for City #448, City Name: lebu
# Retrieving information for City #449, City Name: san patricio
# Retrieving information for City #450, City Name: portales
# Retrieving information for City #451, City Name: salinopolis
# Retrieving information for City #452, City Name: guerrero
# Missing information for City: Guerrero. Skipping city.
# Retrieving information for City #454, City Name: varkaus
# Retrieving information for City #455, City Name: uaua
# Missing information for City: Uaua. Skipping city.
# Retrieving information for City #457, City Name: cotacachi
# Retrieving information for City #458, City Name: kodinsk
# Retrieving information for City #459, City Name: katherine
# Retrieving information for City #460, City Name: skibotn
# Retrieving information for City #461, City Name: esna
# Retrieving information for City #462, City Name: wadi musa
# Retrieving information for City #463, City Name: gorgan
# Retrieving information for City #464, City Name: anadyr
# Retrieving information for City #465, City Name: ust-nera
# Retrieving information for City #466, City Name: kungurtug
# Retrieving information for City #467, City Name: solnechnyy
# Retrieving information for City #468, City Name: calama
# Missing information for City: Calama. Skipping city.
# Missing information for City: Calama. Skipping city.
# Retrieving information for City #471, City Name: tekeli
# Retrieving information for City #472, City Name: ahipara
# Retrieving information for City #473, City Name: wuning
# Missing information for City: Wuning. Skipping city.
# Retrieving information for City #475, City Name: ngunguru
# Retrieving information for City #476, City Name: kiunga
# Missing information for City: Kiunga. Skipping city.
# Retrieving information for City #478, City Name: eydhafushi
# Retrieving information for City #479, City Name: krasnoborsk
# Missing information for City: Krasnoborsk. Skipping city.
# Retrieving information for City #481, City Name: grindavik
# Missing information for City: Grindavik. Skipping city.
# Retrieving information for City #483, City Name: tadine
# Retrieving information for City #484, City Name: natal
# Retrieving information for City #485, City Name: tevaitoa
# Retrieving information for City #486, City Name: borovskoy
# Retrieving information for City #487, City Name: okhotsk
# Retrieving information for City #488, City Name: sitka
# Retrieving information for City #489, City Name: vostok
# Retrieving information for City #490, City Name: tchibanga
# Retrieving information for City #491, City Name: epe
# Retrieving information for City #492, City Name: tamalin
# Retrieving information for City #493, City Name: coquimbo
# Retrieving information for City #494, City Name: feijo
# Retrieving information for City #495, City Name: kutum
# Retrieving information for City #496, City Name: northam
# Retrieving information for City #497, City Name: kralendijk
# Retrieving information for City #498, City Name: kabinda
# Retrieving information for City #499, City Name: shangzhi
# Retrieving information for City #500, City Name: lysyanka
# Retrieving information for City #501, City Name: charyshskoye
# Retrieving information for City #502, City Name: lazaro cardenas
# Retrieving information for City #503, City Name: nelson bay
# Retrieving information for City #504, City Name: tazovskiy
# Retrieving information for City #505, City Name: san cristobal
# Retrieving information for City #506, City Name: vrede
# Retrieving information for City #507, City Name: ambon
# Retrieving information for City #508, City Name: vao
# Missing information for City: Vao. Skipping city.
# Retrieving information for City #510, City Name: puqi
# Retrieving information for City #511, City Name: saint-francois
# Retrieving information for City #512, City Name: huarmey
# Retrieving information for City #513, City Name: megion
# Retrieving information for City #514, City Name: itupiranga
# Retrieving information for City #515, City Name: elk city
# Retrieving information for City #516, City Name: saint-michel-des-saints
# Retrieving information for City #517, City Name: najran
# Retrieving information for City #518, City Name: thessalon
# Retrieving information for City #519, City Name: whitianga
# Retrieving information for City #520, City Name: saint-pierre
# Retrieving information for City #521, City Name: margate
# Retrieving information for City #522, City Name: lorengau
# Retrieving information for City #523, City Name: havoysund
# Retrieving information for City #524, City Name: staritsa
# Retrieving information for City #525, City Name: matara
# Retrieving information for City #526, City Name: dingzhou
# Retrieving information for City #527, City Name: peniche
# Missing information for City: Peniche. Skipping city.
# Retrieving information for City #529, City Name: esil
# Retrieving information for City #530, City Name: west wendover
# Retrieving information for City #531, City Name: lakatoro
# Retrieving information for City #532, City Name: vila nova de milfontes
# Retrieving information for City #533, City Name: tual
# Retrieving information for City #534, City Name: khani
# Retrieving information for City #535, City Name: rabat
# Retrieving information for City #536, City Name: campoverde
# Retrieving information for City #537, City Name: gizo
# Retrieving information for City #538, City Name: usatove
# Retrieving information for City #539, City Name: bam
# Retrieving information for City #540, City Name: porbandar
# Retrieving information for City #541, City Name: mersing
# Retrieving information for City #542, City Name: lakefield
# Retrieving information for City #543, City Name: marrakesh
# Retrieving information for City #544, City Name: vila do maio
# Retrieving information for City #545, City Name: djenne
# Retrieving information for City #546, City Name: chippewa falls
# Retrieving information for City #547, City Name: mount isa
# Retrieving information for City #548, City Name: montepuez
# Retrieving information for City #549, City Name: grootfontein
# Retrieving information for City #550, City Name: batalha
# Retrieving information for City #551, City Name: coos bay
# Missing information for City: Coos Bay. Skipping city.
# Missing information for City: Coos Bay. Skipping city.
# Retrieving information for City #554, City Name: cherskiy
# Retrieving information for City #555, City Name: alihe
# Retrieving information for City #556, City Name: tsaratanana
# Retrieving information for City #557, City Name: ivdel
# Retrieving information for City #558, City Name: shingu
# Retrieving information for City #559, City Name: san francisco menendez
# Retrieving information for City #560, City Name: ileza
# Retrieving information for City #561, City Name: bristol
# Retrieving information for City #562, City Name: east chicago
# Retrieving information for City #563, City Name: yarmouth
# Retrieving information for City #564, City Name: atbasar
# Retrieving information for City #565, City Name: todos santos
# Retrieving information for City #566, City Name: puerto leguizamo
# Retrieving information for City #567, City Name: tihemetsa
# Missing information for City: Tihemetsa. Skipping city.
# Retrieving information for City #569, City Name: shar
# Retrieving information for City #570, City Name: den helder
# Retrieving information for City #571, City Name: vasterhaninge
# Retrieving information for City #572, City Name: sibolga
# Retrieving information for City #573, City Name: inuvik
# Retrieving information for City #574, City Name: ullapool
# Retrieving information for City #575, City Name: novyy urengoy
# Retrieving information for City #576, City Name: raton
# Retrieving information for City #577, City Name: lompoc
# Missing information for City: Lompoc. Skipping city.
# Retrieving information for City #579, City Name: filadelfia
# Retrieving information for City #580, City Name: dreux
# Retrieving information for City #581, City Name: banda aceh
# Retrieving information for City #582, City Name: jinchang
# Retrieving information for City #583, City Name: san ramon
# Retrieving information for City #584, City Name: miyako
# Retrieving information for City #585, City Name: castelvetrano
# Retrieving information for City #586, City Name: zaykovo
# Retrieving information for City #587, City Name: palimbang
# Retrieving information for City #588, City Name: upata
# Retrieving information for City #589, City Name: rabaul
# Retrieving information for City #590, City Name: vila velha
# Retrieving information for City #591, City Name: novaci
# Retrieving information for City #592, City Name: gera
# Retrieving information for City #593, City Name: merritt island
# Missing information for City: Merritt Island. Skipping city.
# Retrieving information for City #595, City Name: viru
# Retrieving information for City #596, City Name: necochea
# Retrieving information for City #597, City Name: duncan
# Retrieving information for City #598, City Name: soyo
# Retrieving information for City #599, City Name: ola
# Retrieving information for City #600, City Name: kamenka
# Retrieving information for City #601, City Name: dapaong
# Retrieving information for City #602, City Name: beyneu
# Retrieving information for City #603, City Name: lagos
# Retrieving information for City #604, City Name: bosanska krupa
# Retrieving information for City #605, City Name: vorotynets
# Retrieving information for City #606, City Name: korcula
# Retrieving information for City #607, City Name: riyadh
# Retrieving information for City #608, City Name: mataram
# Retrieving information for City #609, City Name: luganville
# Missing information for City: Luganville. Skipping city.
# Retrieving information for City #611, City Name: kaputa
# Retrieving information for City #612, City Name: karasjok
# Retrieving information for City #613, City Name: stokmarknes
# Retrieving information for City #614, City Name: nagato
# Retrieving information for City #615, City Name: payson
# Retrieving information for City #616, City Name: vaitape
# Retrieving information for City #617, City Name: ostrovnoy
# Retrieving information for City #618, City Name: jumla
# Missing information for City: Jumla. Skipping city.
# Retrieving information for City #620, City Name: dalianwan
# Retrieving information for City #621, City Name: keti bandar
# Retrieving information for City #622, City Name: bonnyville
# Missing information for City: Bonnyville. Skipping city.
# Retrieving information for City #624, City Name: oussouye
# Missing information for City: Oussouye. Skipping city.
# Retrieving information for City #626, City Name: umm lajj
# Missing information for City: Umm Lajj. Skipping city.
# Retrieving information for City #628, City Name: baykit
# Retrieving information for City #629, City Name: victoria
# Retrieving information for City #630, City Name: angoche
# Missing information for City: Angoche. Skipping city.
# Retrieving information for City #632, City Name: verkhneyarkeyevo
# Retrieving information for City #633, City Name: tiznit
# Retrieving information for City #634, City Name: glenwood springs
# Retrieving information for City #635, City Name: trinidad
# Retrieving information for City #636, City Name: pangkalanbuun
# Retrieving information for City #637, City Name: alofi
# Retrieving information for City #638, City Name: takaka
# Retrieving information for City #639, City Name: port moresby
# Missing information for City: Port Moresby. Skipping city.
# Retrieving information for City #641, City Name: padilla
# Retrieving information for City #642, City Name: mandera
# Retrieving information for City #643, City Name: srikakulam
# Retrieving information for City #644, City Name: mackay
# Retrieving information for City #645, City Name: portalegre
# Retrieving information for City #646, City Name: taos
# Retrieving information for City #647, City Name: micheweni
# Retrieving information for City #648, City Name: libertador general san martin

# %%
print(lat)
# Out:
# [42.65, 72.79, -16.48, 40.29, 39.95, 7.89, 44.67, 22.08, -10.21, 50.7, 64.25, 58.81, -38.31, -53.16, -7.16, 15.86, -34.48, 21.78, -42.48, 1.33, 77.48, 60.75, -12.74, -34.53, -0.6, 71.97, -23.12, 8.07, -33.21, -27.83, -46.19, 46.54, 71.98, 66.83, 7.42, 6.3, -9.07, 61.01, 52.47, -33.69, -54.81, 18.69, 62.45, -9.8, 65.61, 18.9, 30.04, 20.71, 34.92, -33.93, -20.25, 45.6, -51.62, -33.59, -18.09, 43.26, 40.82, 38.52, 5.43, 35.74, -0.74, 33.93, 3.07, -16.84, -42.78, 73.51, 37.14, -0.87, 33.83, -31.43, 69.7, -22.97, 27.97, 44.42, -23.58, -13.71, 14.9, 16.86, 12.99, 15.34, 55.74, 5.88, -20.07, -8.93, -33.64, 30.85, -2.37, 36.55, 39.31, 66.77, 22.53, 67.47, -20.74, -9.11, 22.57, -5.81, 46.71, 63.75, 39.62, -41.87, -30.97, 53.1, -20.34, 17.01, 47.61, 66.56, 36.41, 54.6, 45.36, 13.08, -21.21, -21.64, 19.91, 55.34, -46.43, 29.96, 19.71, -34.72, -28.55, -34.42, 63.59, 59.2, -19.55, 35.31, 50.68, 41.19, 21.32, -15.33, 65.28, 40.42, 53.41, 41.28, 60.06, 48.01, 52.86, -35.71, 54.77, 20.62, 62.23, 47.92, 64.42, 52.95, -20.63, -34.05, -31.54, -46.28, -33.86, -25.24, -20.41, 67.86, -33.02, 11.67, -45.75, 64.43, -36.72, -0.72, -46.13, 61.47, -34.58, 55.45, 69.49, 61.99, 55.09, -6.97, 63.05, 3.38, 36.62, 35.73, 52.34, -45.87, 22.48, 50.56, 68.54, 9.8, 64.86, 44.76, -42.88, 58.79, 9.55, 39.76, 23.99, 18.56, 18.39, -3.66, 55.82, -26.02, 24.34, -5.23, 62.53, 11.92, 70.47, 54.11, 42.89, -31.62, 59.43, 2.82, 35.03, 45.18, 13.81, 20.62, 59.64, 12.18, 60.79, -20.31, 31.33, 6.8, 11.28, -34.04, -34.42, -12.06, 59.7, 41.64, 38.73, -11.38, -2.54, 48.64, 50.1, 4.14, 49.72, -30.17, 37.72, 53.14, 41.19, 49.49, 70.24, 34.72, 7.14, -25.17, 67.55, 4.82, 39.45, 17.08, 66.15, 65.42, 44.08, 4.87, 56.76, -26.65, -31.66, 51.01, -11.1, 25.74, 14.25, 41.42, -27.69, 5.36, 30.3, 61.94, 55.65, -19.98, 69.38, -28.65, 49.65, -25.65, 40.6, 43.65, 43.32, 5.35, 4.94, 25.81, 55.22, 38.1, -28.95, 8.04, 55.1, 6.33, -20.67, -23.87, 60.47, -10.62, 33.6, 52.85, 71.64, 42.84, 51.64, 70.62, 46.77, 62.1, 51.76, 65.58, 54.34, 44.17, 5.67, -6.22, -6.53, 6.37, 69.22, -6.85, -33.01, -3.2, 44.03, 37.63, 78.22, 9.98, -22.95, -40.81, -0.92, -35.36, -6.2, 26.33, -4.09, 29.55, 40.47, 35.86, -22.4, 14.07, -25.3, 28.58, -41.05, 69.44, 19.55, -23.7, -8.28, 61.99, 32.12, 32.93, 22.89, 42.77, -33.73, 68.22, 68.01, 20.93, -39.28, 30.78, 49.78, 60.91, -45.41, -24.97, 26.99, 48.97, 31.21, 40.87, -26.39, 25.1, -20.54, 48.04, 56.2, 6.41, 12.2, 31.35, 4.27, 15.09, -27.78, 39.12, 60.45, 12.37, -28.36, -23.99, 60.55, 53.98, -5.2, 43.11, 68.06, -14.88, 70.03, -6.1, -6.22, -5.99, 16.61, 71.03, 0.05, 28.28, 36.2, -30.3, -22.28, 24.47, -37.83, 47.66, 28.21, 7.74, 67.46, 43.74, -14.25, 27.69, 12.18, 21.23, 32.45, -24.93, 40.73, -2.57, 16.17, 20.89, 14.32, 67.67, 9.28, 10.57, -9.01, 65.85, -27.03, -8.63, 10.05, 31.65, -39.19, 30.75, 11, 50.33, -11.37, -4.8, -6.48, 44.78, -39.94, 60.71, 10.07, 42.45, 16.18, 15.46, 63.44, 8.96, -26.98, 34.19, -0.61, -24.19, 62.32, -9.84, 0.3, 58.6, -14.47, 69.39, 45.2, 30.32, 36.84, 64.73, 64.57, 50.6, 50.72, -22.46, 44.86, -35.17, 29.26, -35.62, -6.12, 5.1, 61.56, 63.84, -21.55, -5.81, -16.78, 53.8, 59.36, 37.17, 46.45, -2.92, 52.18, 21.35, -29.95, -3.63, 14.2, -31.65, 12.15, -6.14, 45.21, 49.25, 51.4, 28.39, -32.72, 67.47, 14.68, -27.43, 47.55, 59.1, 29.72, 46.42, -10.07, 61.04, -5.13, 35.41, 46.68, 17.54, 46.26, -36.83, 48.95, -43.03, -2.02, 71, 56.51, -3.48, 38.51, 39.36, 51.96, 40.74, -16.11, 37.72, -5.67, 41.96, 34.02, -0.91, 31.8, 46.54, 29.11, 21.64, 2.43, 44.42, 31.63, 15.13, 13.91, 44.94, -20.73, -13.13, -19.56, -9.67, 43.37, 68.75, 50.57, -16.8, 60.7, 33.72, 13.84, 61.05, 51.45, 41.64, 43.84, 51.81, 23.45, -0.19, 58.15, 7.3, 52.96, 59.12, 1.74, 68.36, 57.9, 66.08, 36.9, 34.64, -22.35, 48.74, 5.56, 38.52, 12.92, 33.63, 37.68, 57.56, 14.9, 8.02, -4.2, -3.71, 45.17, 50.88, 28.54, 57.74, -38.55, 34.5, -6.13, 59.58, 48.03, 10.86, 45.32, 6.46, 44.88, 56.06, 42.96, 24.63, -5.32, -15.51, -8.47, 69.47, 68.56, 34.35, 40.04, -16.52, 68.05, 29.28, 39.03, 24.14, 54.27, 12.49, 25.02, 61. ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(weather_response)
weather_df.head()
# Out:
#                                                    0
# 0  b'{"coord":{"lon":-64.79,"lat":-23.81},"weathe...
# 1  b'odel","main":{"temp":79.74,"pressure":1009,"...
# 2  b'ind":{"speed":5.17,"deg":86},"clouds":{"all"...
# 3  b',"timezone":-10800,"id":3846915,"name":"Libe...

# %%
weather_df.to_csv("Beth_weather_data.csv",index=False)

# %%
hum
# Out:
# [71,
#  84,
#  80,
#  23,
#  56,
#  78,
#  55,
#  88,
#  19,
#  100,
#  64,
#  85,
#  40,
#  55,
#  76,
#  73,
#  59,
#  71,
#  100,
#  57,
#  90,
#  97,
#  61,
#  48,
#  64,
#  97,
#  80,
#  54,
#  86,
#  7,
#  55,
#  74,
#  97,
#  88,
#  81,
#  62,
#  86,
#  99,
#  87,
#  59,
#  49,
#  10,
#  85,
#  78,
#  86,
#  11,
#  66,
#  88,
#  53,
#  49,
#  57,
#  87,
#  17,
#  77,
#  38,
#  80,
#  72,
#  72,
#  78,
#  100,
#  73,
#  77,
#  75,
#  49,
#  66,
#  95,
#  82,
#  84,
#  100,
#  100,
#  82,
#  52,
#  36,
#  75,
#  84,
#  30,
#  66,
#  74,
#  86,
#  88,
#  92,
#  59,
#  95,
#  84,
#  61,
#  26,
#  70,
#  74,
#  57,
#  94,
#  78,
#  94,
#  59,
#  79,
#  72,
#  43,
#  80,
#  79,
#  52,
#  100,
#  4,
#  90,
#  73,
#  74,
#  91,
#  87,
#  48,
#  82,
#  86,
#  83,
#  60,
#  45,
#  69,
#  93,
#  35,
#  70,
#  73,
#  79,
#  54,
#  64,
#  92,
#  96,
#  81,
#  48,
#  90,
#  82,
#  78,
#  18,
#  92,
#  62,
#  62,
#  67,
#  96,
#  93,
#  91,
#  98,
#  100,
#  93,
#  52,
#  33,
#  89,
#  43,
#  59,
#  71,
#  15,
#  71,
#  87,
#  17,
#  73,
#  92,
#  68,
#  75,
#  62,
#  91,
#  67,
#  74,
#  55,
#  72,
#  100,
#  90,
#  75,
#  48,
#  58,
#  55,
#  88,
#  46,
#  23,
#  87,
#  79,
#  62,
#  65,
#  90,
#  89,
#  41,
#  100,
#  52,
#  66,
#  80,
#  74,
#  79,
#  100,
#  64,
#  17,
#  78,
#  100,
#  11,
#  83,
#  48,
#  95,
#  78,
#  73,
#  93,
#  93,
#  49,
#  87,
#  52,
#  68,
#  100,
#  8,
#  74,
#  93,
#  89,
#  78,
#  64,
#  70,
#  70,
#  83,
#  67,
#  68,
#  82,
#  93,
#  49,
#  68,
#  70,
#  81,
#  93,
#  92,
#  71,
#  85,
#  80,
#  68,
#  92,
#  48,
#  67,
#  92,
#  51,
#  59,
#  39,
#  92,
#  68,
#  68,
#  84,
#  79,
#  55,
#  69,
#  79,
#  89,
#  77,
#  33,
#  61,
#  62,
#  37,
#  71,
#  72,
#  78,
#  85,
#  75,
#  95,
#  59,
#  73,
#  80,
#  83,
#  94,
#  83,
#  75,
#  61,
#  59,
#  75,
#  66,
#  80,
#  80,
#  100,
#  82,
#  69,
#  100,
#  94,
#  45,
#  73,
#  95,
#  90,
#  22,
#  74,
#  96,
#  31,
#  92,
#  87,
#  68,
#  96,
#  68,
#  88,
#  93,
#  44,
#  67,
#  32,
#  42,
#  74,
#  49,
#  29,
#  28,
#  74,
#  71,
#  34,
#  57,
#  28,
#  19,
#  14,
#  97,
#  100,
#  26,
#  30,
#  48,
#  72,
#  70,
#  48,
#  60,
#  72,
#  88,
#  64,
#  93,
#  85,
#  74,
#  30,
#  44,
#  41,
#  65,
#  42,
#  78,
#  100,
#  34,
#  100,
#  95,
#  23,
#  76,
#  94,
#  90,
#  58,
#  87,
#  62,
#  91,
#  61,
#  21,
#  49,
#  17,
#  88,
#  48,
#  66,
#  56,
#  74,
#  74,
#  71,
#  38,
#  88,
#  39,
#  67,
#  69,
#  34,
#  79,
#  42,
#  93,
#  70,
#  55,
#  84,
#  87,
#  56,
#  92,
#  78,
#  30,
#  55,
#  64,
#  78,
#  63,
#  67,
#  72,
#  77,
#  72,
#  58,
#  87,
#  87,
#  81,
#  50,
#  95,
#  82,
#  73,
#  57,
#  21,
#  74,
#  46,
#  93,
#  45,
#  79,
#  94,
#  78,
#  12,
#  51,
#  76,
#  64,
#  75,
#  93,
#  93,
#  80,
#  28,
#  73,
#  97,
#  42,
#  88,
#  100,
#  19,
#  79,
#  81,
#  7,
#  50,
#  86,
#  82,
#  76,
#  66,
#  7,
#  75,
#  59,
#  59,
#  51,
#  81,
#  68,
#  100,
#  38,
#  77,
#  64,
#  48,
#  63,
#  53,
#  52,
#  82,
#  92,
#  100,
#  78,
#  45,
#  13,
#  63,
#  77,
#  94,
#  89,
#  99,
#  66,
#  91,
#  60,
#  72,
#  62,
#  82,
#  80,
#  76,
#  61,
#  88,
#  84,
#  82,
#  88,
#  82,
#  94,
#  16,
#  71,
#  74,
#  74,
#  43,
#  76,
#  82,
#  81,
#  100,
#  92,
#  82,
#  10,
#  93,
#  99,
#  51,
#  81,
#  51,
#  78,
#  66,
#  64,
#  9,
#  23,
#  74,
#  95,
#  93,
#  66,
#  76,
#  79,
#  88,
#  77,
#  93,
#  72,
#  74,
#  50,
#  85,
#  95,
#  82,
#  52,
#  93,
#  71,
#  61,
#  82,
#  25,
#  76,
#  75,
#  86,
#  44,
#  49,
#  11,
#  86,
#  39,
#  46,
#  24,
#  43,
#  93,
#  87,
#  65,
#  46,
#  91,
#  64,
#  65,
#  97,
#  81,
#  69,
#  70,
#  70,
#  78,
#  90,
#  100,
#  62,
#  87,
#  80,
#  94,
#  100,
#  90,
#  93,
#  62,
#  55,
#  31,
#  82,
#  88,
#  44,
#  83,
#  93,
#  64,
#  92,
#  78,
#  64,
#  82,
#  55,
#  95,
#  67,
#  61,
#  93,
#  41,
#  93,
#  74,
#  89,
#  71,
#  35,
#  72,
#  78,
#  75,
#  85,
#  77,
#  24,
#  95,
#  97,
#  25,
#  84,
#  72,
#  77,
#  79,
#  80,
#  89,
#  90,
#  45,
#  67,
#  74,
#  35,
#  52,
#  90,
#  83,
#  72,
#  90,
#  54,
#  32,
#  74,
#  90,
#  68,
#  87,
#  88,
#  78,
#  40,
#  81,
#  100,
#  56,
#  21,
#  80,
#  58]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(lat, temp_max, marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(lat, hum, marker="o")

# Incorporate the other graph properties
plt.title("Humidity in World Cities")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(lat, cloud, marker="o")

# Incorporate the other graph properties
plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(lat, wind, marker="o")

# Incorporate the other graph properties
plt.title("Wind in World Cities")
plt.ylabel("Wind")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindInWorldCities.png")

# Show plot
plt.show()
